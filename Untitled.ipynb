# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('cleaned_data/3rdsemA.csv')

# %%
data.head()
# Out:
#    Unnamed: 1          Unnamed: 2  IN  EX   T GL  GP RESULT  IN.1  EX.1  ...  \
# 0  4RA21CS001        ABHISHEK D M  49  49  98  O  10   PASS    50    35  ...
# 1  4RA21CS002           AKASH V R  46  28  74  A   8   PASS    47    12  ...
# 2  4RA21CS003          AMULYA M D  33   9  42  P   4   FAIL    43    18  ...
# 3  4RA21CS004  ANANYA KOWSHIK K N  37  21  58  B   6   PASS    46    20  ...
# 4  4RA21CS005        ARJUN THAKUR  32   7  39  F   0   FAIL    40    21  ...
#
#    Unnamed: 51 Unnamed: 52  Unnamed: 53 Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0          744         171     9.500000      93.000            0          FCD
# 1          636         141     7.833333      79.500            1         FAIL
# 2          557         124     6.888889      69.625            1         FAIL
# 3          604         129     7.166667      75.500            0          FCD
# 4          547          96     5.333333      68.375            2         FAIL
#
#    1st  2nd  3rd Unnamed: 61
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     Unnamed: 1            Unnamed: 2  IN  EX   T  GL  GP RESULT  IN.1  EX.1  \
# 0   4RA21CS001          ABHISHEK D M  49  49  98   O  10   PASS    50    35
# 1   4RA21CS002             AKASH V R  46  28  74   A   8   PASS    47    12
# 2   4RA21CS003            AMULYA M D  33   9  42   P   4   FAIL    43    18
# 3   4RA21CS004    ANANYA KOWSHIK K N  37  21  58   B   6   PASS    46    20
# 4   4RA21CS005          ARJUN THAKUR  32   7  39   F   0   FAIL    40    21
# ..         ...                   ...  ..  ..  ..  ..  ..    ...   ...   ...
# 62  4RA21CS064           PREKSHA H D  47  25  72   A   8   PASS    46    11
# 63  4RA21CS065             PUNYA K N  45  22  67  B+   7   PASS    46    18
# 64  4RA21CS066       RACHANA M GOWDA  50  32  82  A+   9   PASS    48    30
# 65  4RA21CS067          RACHITHA R J  36  18  54   C   5   PASS    47    18
# 66  4RA21CS068  RAKSHIT KENCHANNAVAR  50  49  99   O  10   PASS    50    24
#
# ...

# %%
data.describe()
# Out:
#               IN         EX          T         GP       IN.1       EX.1  \
# count  67.000000  67.000000  67.000000  67.000000  67.000000  67.000000
# mean   43.134328  21.477612  64.611940   6.626866  45.134328  20.761194
# std     6.144462   9.956509  14.685548   2.130840   3.279392   7.531931
# min    26.000000   2.000000  30.000000   0.000000  37.000000   5.000000
# 25%    38.500000  18.000000  56.500000   6.000000  43.500000  18.000000
# 50%    45.000000  20.000000  66.000000   7.000000  46.000000  19.000000
# 75%    49.000000  26.500000  75.000000   8.000000  47.000000  24.000000
# max    50.000000  49.000000  99.000000  10.000000  50.000000  38.000000
#
#              T.1       GP.1       IN.2       EX.2  ...       GP.7  \
# count  67.000000  67.000000  67.000000  66.000000  ...  67.000000
# mean   65.895522   7.029851  45.164179  19.530303  ...   9.880597
# std     9.736116   1.205670   4.347054   7.559446  ...   0.326709
# ...

# %%
df = data

# %%
df.columns.str.replace('Unnamed: 1','USN')
# Out:
# Index(['USN', 'Unnamed: 2', 'IN', 'EX', 'T', 'GL', 'GP', 'RESULT', 'IN.1',
#        'EX.1', 'T.1', 'GL.1', 'GP.1', 'RESULT.1', 'IN.2', 'EX.2', 'T.2',
#        'GL.2', 'GP.2', 'RESULT.2', 'IN.3', 'EX.3', 'T.3', 'GL.3', 'GP.3',
#        'RESULT.3', 'IN.4', 'EX.4', 'T.4', 'GL.4', 'GP.4', 'RESULT.4', 'IN.5',
#        'EX.5', 'T.5', 'GL.5', 'GP.5', 'RESULT.5', 'IN.6', 'EX.6', 'T.6',
#        'GL.6', 'GP.6', 'RESULT.6', 'IN.7', 'EX.7', 'T.7', 'GL.7', 'GP.7',
#        'RESULT.7', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54',
#        'Unnamed: 55', 'Unnamed: 56', '1st', '2nd', '3rd', 'Unnamed: 61'],
#       dtype='object')

# %%
df.head(3)
# Out:
#           USN    Unnamed: 2  IN  EX   T GL  GP RESULT  IN.1  EX.1  ...  \
# 0  4RA21CS001  ABHISHEK D M  49  49  98  O  10   PASS    50    35  ...
# 1  4RA21CS002     AKASH V R  46  28  74  A   8   PASS    47    12  ...
# 2  4RA21CS003    AMULYA M D  33   9  42  P   4   FAIL    43    18  ...
#
#    Unnamed: 51 Unnamed: 52  Unnamed: 53 Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0          744         171     9.500000      93.000            0          FCD
# 1          636         141     7.833333      79.500            1         FAIL
# 2          557         124     6.888889      69.625            1         FAIL
#
#    1st  2nd  3rd Unnamed: 61
# 0  190  174  171    9.224138
# 1  154  151  141    7.689655
# 2  146  100  124    6.379310
#
# [3 rows x 60 columns]

# %%
df = df.rename(columns={'Unnamed: 1':'USN'})

# %%
df.head(2)
# Out:
#           USN    Unnamed: 2  IN  EX   T GL  GP RESULT  IN.1  EX.1  ...  \
# 0  4RA21CS001  ABHISHEK D M  49  49  98  O  10   PASS    50    35  ...
# 1  4RA21CS002     AKASH V R  46  28  74  A   8   PASS    47    12  ...
#
#    Unnamed: 51 Unnamed: 52  Unnamed: 53 Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0          744         171     9.500000        93.0            0          FCD
# 1          636         141     7.833333        79.5            1         FAIL
#
#    1st  2nd  3rd Unnamed: 61
# 0  190  174  171    9.224138
# 1  154  151  141    7.689655
#
# [2 rows x 60 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ABHISH~1\AppData\Local\Temp/ipykernel_16848/1061005575.py in <module>
# ----> 1 df.drop(columns=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...
